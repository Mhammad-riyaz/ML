# %% [markdown]
# <a href="https://colab.research.google.com/github/Mhammad-riyaz/ML/blob/main/linear-algebra-intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.linspace(0,50,1000)

# %%
d_r = 2.5*t
d_s = 3*(t-5)

# %%
fig,ax = plt.subplots()
plt.title = ('Catching a Robber ')
plt.xlabel = ('time (in mins)')
plt.ylabel = ('distance (in km)')
ax.set_xlim([0,40])
ax.set_ylim([0,100])
ax.plot(t,d_r,c='red')
ax.plot(t,d_s,c='blue')
plt.axvline(x=30,color="green",linestyle="--")
plt.axhline(y=75,color="green",linestyle="--")
